# %% [markdown]
# ## AI Governance Applications

# %%
# Exercise 01 - Your First Python Code
# Application: AI Governance

# %%
risk_score = 25
control_count = 4
print(risk_score)
print(control_count)
# Out:
# 25
# 4

# %%
system_name = "AI Quality Assistant"
risk_score = 7.5
control_count = 12
governance_status = "Under Review"
approval_required = True
print(system_name)
print(risk_score)
print(governance_status)
print(approval_required)
# Out:
# AI Quality Assistant
# 7.5
# Under Review
# True
