# %%
policy_id = "AIGOV-POL-021"
risk_description = "Model output may contain unverified information"

print(policy_id.split("-"))
print(risk_description.find("unverified"))
print(risk_description.replace("unverified", "potentially unverified"))
# Out:
# ['AIGOV', 'POL', '021']
# 25
# Model output may contain potentially unverified information
